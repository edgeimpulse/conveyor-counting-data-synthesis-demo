# %% [markdown]
# # Conveyor Belt Dataset Generation
#
# This notebook takes you through an example of how to automatically generate an image dataset for conveyor belt detection based on just a few source images.
#
# First we need to install the dependencies for Imagemagick & Wand, which we'll use to make our image composites later

# %%
# !pip install wand
# !pip install matplotlib
# !brew install freetype imagemagick@6
# !export DYLD_FALLBACK_LIBRARY_PATH=/usr/local/opt/imagemagick@6/lib/
# Out:
# Requirement already satisfied: wand in /Users/jbruges/.pyenv/versions/3.11.0rc2/lib/python3.11/site-packages (0.6.11)
#
# [notice] A new release of pip available: 22.3.1 -> 23.0
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: matplotlib in /Users/jbruges/.pyenv/versions/3.11.0rc2/lib/python3.11/site-packages (3.7.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/jbruges/.pyenv/versions/3.11.0rc2/lib/python3.11/site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /Users/jbruges/.pyenv/versions/3.11.0rc2/lib/python3.11/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/jbruges/.pyenv/versions/3.11.0rc2/lib/python3.11/site-packages (from matplotlib) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/jbruges/.pyenv/versions/3.11.0rc2/lib/python3.11/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in /Users/jbruges/.pyenv/versions/3.11.0rc2/lib/python3.11/site-packages (from matplotlib) (1.23.4)
# Requirement already satisfied: packaging>=20.0 in /Users/jbruges/.pyenv/versions/3.11.0rc2/lib/python3.11/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /Users/jbruges/.pyenv/versions/3.11.0rc2/lib/python3.11/site-packages (from matplotlib) (9.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/jbruges/.pyenv/versions/3.11.0rc2/lib/python3.11/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/jbruges/.pyenv/versions/3.11.0rc2/lib/python3.11/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/jbruges/.pyenv/versions/3.11.0rc2/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
#
# [notice] A new release of pip available: 22.3.1 -> 23.0
# [notice] To update, run: pip install --upgrade pip
# Running `brew update --auto-update`...
# ==> Auto-updated Homebrew!
# Updated 1 tap (snyk/tap).
# ==> Downloading https://formulae.brew.sh/api/formula.json
# ######################################################################## 100.0%
# ==> Downloading https://formulae.brew.sh/api/cask.json
# ######################################################################## 100.0%
#
# You have 15 outdated formulae installed.
# You can upgrade them with brew upgrade
# or list them with brew outdated.
#
# Warning: freetype 2.13.0 is already installed and up-to-date.
# To reinstall 2.13.0, run:
#   brew reinstall freetype
# Warning: imagemagick@6 6.9.12-77 is already installed and up-to-date.
# To reinstall 6.9.12-77, run:
#   brew reinstall imagemagick@6

# %% [markdown]
# We need to set out a bounding box area where we want to place our objects for the image composite:

# %%
from wand.image import Image
from wand.drawing import Drawing
from wand.color import Color

# Load the background image
background = Image(filename ='empty.bmp')

# Define the dimensions of the background image
background_width = background.width
background_height = background.height

# Define the dimensions of the area where objects can be placed
object_area_left = 25
object_area_top = 0
object_area_width = background_width-80
object_area_height = background_height


# Draw the bounding box on the image
with Drawing() as draw:
    draw.stroke_color = Color('red')
    draw.stroke_width = 2
    draw.fill_opacity = 0
    draw.rectangle(left=object_area_left, top=object_area_top, right=object_area_left+object_area_width, bottom=object_area_top+object_area_height)
    draw(background)

# Save the image with the bounding box
background
# Out:
# <wand.image.Image: 09a28fa 'BMP3' (320x240)>

# %% [markdown]
# Now we can load a test image and add in some objects. This script places up to 8 nuts onto the conveyor belt within the bounds set before, rotating them and ensuring there is no overlap.

# %%
from wand.image import Image
import random
bg_image= Image(filename='empty.bmp')
obj_image = Image(filename='bottomcrop.bmp')
canvas = Image(width=bg_image.width, height=bg_image.height) 
objects = []
label = 'm5_nut'
# Composite the background image onto the canvas
canvas.composite(bg_image, 0, 0)
# Composite the object image onto the canvas with a random x and y position within the canvas
for i in range(random.randrange(8)):
    obj_image.rotate(random.uniform(0, 360))
    object_width = obj_image.width
    object_height = obj_image.height

    # Place the object in a random position within the defined area
    x = random.randint(object_area_left, object_area_left + object_area_width - object_width)
    y = random.randint(object_area_top, object_area_top + object_area_height - object_height)

    # Check if the object overlaps with any previously placed objects
    overlap = False
    if len(objects)>0:
        for j in range(i-1):
            if (x < objects[j]['x'] + objects[j]['width'] and x + object_width > objects[j]['x'] and
                y < objects[j]['y'] + objects[j]['height'] and y + object_height > objects[j]['y']):
                overlap = True
                break
    # If there is no overlap, place the object on the background image
    if not overlap:
        canvas.composite(obj_image, x, y)
        objects.append({'label': label, 'x': x, 'y': y, 'width': object_width, 'height': object_height})

canvas
# Out:
# <wand.image.Image: cd60f8f '' (320x240)>

# %% [markdown]
# Now we can extend this script to generate a dataset:
# - First we create a list of image objects with different background frames and different angles of our object
# - Next we generate our dataset by combining different objects and background images in random combination, with added motion blur and rotation.
# - Finally we place the bounding box labels (the coordinates, width and height of each object placed in the image) into a bounding-box json file ready for upload to studio

# %%
from wand.image import Image
from wand.color import Color
import random
import json


# Define the max number of objects to place on the background image
num_objects = 8

num_images = 400
bg_images = [Image(filename ='empty.bmp'),Image(filename ='empty2.bmp'),Image(filename ='empty3.bmp'),Image(filename ='empty4.bmp'),Image(filename ='empty5.bmp'),Image(filename ='empty6.bmp'),Image(filename ='empty7.bmp')]
obj_images = [Image(filename='bottomcrop.bmp'),Image(filename='topcrop.bmp'),Image(filename='sidecrop.bmp')]

label = 'm5_nut'

bbox_json = {
    "version": 1,
    "type": "bounding-box-labels",
    "boundingBoxes": {
        
    }
}

for n in range(num_images):
    objects = []
    background = bg_images[random.randrange(len(bg_images))].clone()

    # Define the dimensions of the background image
    background_width = background.width
    background_height = background.height
    # Define the dimensions of the area where objects can be placed
    object_area_left = 25
    object_area_top = 0
    object_area_width = background_width-80
    object_area_height = background_height
    
    blur_amount = random.randrange(8)
    
    background.motion_blur(sigma=blur_amount, angle=-90)

    
    # Create a new image for each object
    for i in range(random.randrange(num_objects)):
        
        # Load the object image
        object_image = obj_images[random.randrange(len(obj_images))].clone()
        object_image.rotate(random.uniform(0, 360))

        object_width = object_image.width
        object_height = object_image.height

        object_image.resize(object_width, object_height)
        object_image.motion_blur(sigma=blur_amount, angle=-90)

        # Place the object in a random position within the defined area

        x = random.randint(object_area_left, object_area_left + object_area_width - object_width)
        y = random.randint(object_area_top, object_area_top + object_area_height - object_height)



        # Check if the object overlaps with any previously placed objects
        overlap = False
        if len(objects)>0:
            for j in range(len(objects)):
                if (x < objects[j]['x'] + objects[j]['width'] and x + object_width > objects[j]['x'] and
                    y < objects[j]['y'] + objects[j]['height'] and y + object_height > objects[j]['y']):
                    overlap = True
                    break
        # If there is no overlap, place the object on the background image
        if not overlap:
            background.composite(object_image, x, y)

            # Add the object's position and size to the list of placed objects
            objects.append({'label': label, 'x': x, 'y': y, 'width': object_width, 'height': object_height})

    # Save the new image with objects placed on top of the background
    background.save(filename=f'output/new_image{n}.png')
    bbox_json["boundingBoxes"].update({f'new_image{n}.png': objects})

with open('output/bounding_boxes.labels','w+') as file:
        json.dump(bbox_json, file, indent = 4)

# %% [markdown]
# Here you can see a sample of some of the auto-generated images from the dataset. These will provide a good basis for developing an object detection model

# %%
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Define the folder containing the images
folder_path = './output'

# Get a list of all the image files in the folder
image_files = [f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f)) and f.endswith('.png')]

# Set up the plot
fig, axs = plt.subplots(nrows=10, ncols=10, figsize=(10, 10))

# Loop through each image and plot it in a grid cell
for i in range(10):
    for j in range(10):
        img = mpimg.imread(os.path.join(folder_path, image_files[i*10+j]))
        axs[i,j].imshow(img)
        axs[i,j].axis('off')

# Make the plot look clean
fig.subplots_adjust(hspace=0, wspace=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# Finally, we must upload these files using the edge-impulse-uploader cli tool. This takes in a folder of data files and a bounding-boxes.labels file which contains labels for training.

# %%
# !cd output && edge-impulse-uploader *
# Out:
# Edge Impulse uploader v1.17.0
# Endpoints:
#     API:         https://studio.edgeimpulse.com
#     Ingestion:   https://ingestion.edgeimpulse.com
#
# Upload configuration:
#     Label:       Not set, will be infered from file name
#     Category:    training
#     Project:     Conveyor Belt Demo V1 (ID: 187740)
#
# [  1/400] Failed to upload new_image109.png An item with this hash already exists (ids: 183208385)
# [  2/400] Failed to upload new_image1.png An item with this hash already exists (ids: 183208401)
# [  3/400] Failed to upload new_image100.png An item with this hash already exists (ids: 183208396)
# [  4/400] Failed to upload new_image104.png An item with this hash already exists (ids: 183208386)
# [  5/400] Failed to upload new_image115.png An item with this hash already exists (ids: 183208391)
# [  6/400] Failed to upload new_image106.png An item with this hash already exists (ids: 183208392)
# [  7/400] Failed to upload new_image11.png An item with this hash already exists (ids: 183208387)
# [  8/400] Failed to upload new_image113.png An item with this hash already exists (ids: 183208393)
# [  9/400] Failed to upload new_image101.png An item with this hash already exists (ids: 183208397)
# [ 10/400] Failed to upload new_image114.png An item with this hash already exists (ids: 183208395)
# [ 11/400] Failed to upload new_image10.png An item with this hash already exists (ids: 183208384)
# [ 12/400] Failed to upload new_image110.png An item with this hash already exists (ids: 183208394)
# [ 13/400] Failed to upload new_image112.png An item with this hash already exists (ids: 183208389)
# [ 14/400] Failed to upload new_image103.png An item with this hash already exists (ids: 183208400)
# [ 15/400] Uploading new_image111.png OK (1117 ms)
# [ 16/400] Uploading new_image116.png OK (499 ms)
# [ 17/400] Uploading new_image105.png OK (1182 ms)
# [ 18/400] Uploading new_image12.png OK (433 ms)
# [ 19/400] Failed to upload new_image108.png An item with this hash already exists (ids: 183208390)
# [ 20/400] Failed to upload new_image102.png An item with this hash already exists (ids: 183208398)
# [ 21/400] Failed to upload new_image0.png An item with this hash already exists (ids: 183208388)
# [ 22/400] Uploading new_image122.png OK (464 ms)
# [ 23/400] Failed to upload new_image107.png An item with this hash already exists (ids: 183208399)
# [ 24/400] Uploading new_image119.png OK (686 ms)
# [ 25/400] Uploading new_image118.png OK (827 ms)
# [ 26/400] Uploading new_image121.png OK (722 ms)
# [ 27/400] Uploading new_image124.png OK (670 ms)
# [ 28/400] Uploading new_image117.png OK (926 ms)
# [ 29/400] Uploading new_image131.png OK (477 ms)
# [ 30/400] Uploading new_image130.png OK (500 ms)
# [ 31/400] Uploading new_image125.png OK (783 ms)
# [ 32/400] Uploading new_image135.png OK (392 ms)
# [ 33/400] Uploading new_image123.png OK (865 ms)
# [ 34/400] Uploading new_image127.png OK (814 ms)
# [ 35/400] Uploading new_image120.png OK (963 ms)
# [ 36/400] Uploading new_image134.png OK (582 ms)
# [ 37/400] Uploading new_image129.png OK (692 ms)
# [ 38/400] Uploading new_image13.png OK (685 ms)
# [ 39/400] Uploading new_image126.png OK (882 ms)
# [ 40/400] Uploading new_image140.png OK (250 ms)
# [ 41/400] Uploading new_image137.png OK (542 ms)
# [ 42/400] Uploading new_image138.png OK (630 ms)
# [ 43/400] Uploading new_image139.png OK (657 ms)
# [ 44/400] Uploading new_image142.png OK (580 ms)
# [ 45/400] Uploading new_image143.png OK (583 ms)
# [ 46/400] Uploading new_image141.png OK (634 ms)
# [ 47/400] Uploading new_image133.png OK (1178 ms)
# [ 48/400] Uploading new_image14.png OK (829 ms)
# [ 49/400] Uploading new_image151.png OK (532 ms)
# [ 50/400] Uploading new_image15.png OK (630 ms)
# [ 51/400] Uploading new_image128.png OK (1391 ms)
# [ 52/400] Uploading new_image147.png OK (680 ms)
# [ 53/400] Uploading new_image144.png OK (743 ms)
# [ 54/400] Uploading new_image145.png OK (717 ms)
# [ 55/400] Uploading new_image148.png OK (709 ms)
# [ 56/400] Uploading new_image149.png OK (710 ms)
# [ 57/400] Uploading new_image153.png OK (341 ms)
# [ 58/400] Uploading new_image136.png OK (1158 ms)
# [ 59/400] Uploading new_image150.png OK (765 ms)
# [ 60/400] Uploading new_image146.png OK (812 ms)
# [ 61/400] Uploading new_image132.png OK (1402 ms)
# [ 62/400] Uploading new_image155.png OK (378 ms)
# [ 63/400] Uploading new_image156.png OK (399 ms)
# [ 64/400] Uploading new_image152.png OK (756 ms)
# [ 65/400] Uploading new_image154.png OK (501 ms)
# [ 66/400] Uploading new_image165.png OK (423 ms)
# [ 67/400] Uploading new_image163.png OK (461 ms)
# [ 68/400] Uploading new_image161.png OK (579 ms)
# [ 69/400] Uploading new_image157.png OK (758 ms)
# [ 70/400] Uploading new_image168.png OK (552 ms)
# [ 71/400] Uploading new_image16.png OK (665 ms)
# [ 72/400] Uploading new_image164.png OK (638 ms)
# [ 73/400] Uploading new_image162.png OK (661 ms)
# [ 74/400] Uploading new_image169.png OK (633 ms)
# [ 75/400] Uploading new_image17.png OK (646 ms)
# [ 76/400] Uploading new_image159.png OK (843 ms)
# [ 77/400] Uploading new_image175.png OK (343 ms)
# [ 78/400] Uploading new_image171.png OK (686 ms)
# [ 79/400] Uploading new_image160.png OK (904 ms)
# [ 80/400] Uploading new_image167.png OK (845 ms)
# [ 81/400] Uploading new_image176.png OK (484 ms)
# [ 82/400] Uploading new_image178.png OK (423 ms)
# [ 83/400] Uploading new_image172.png OK (822 ms)
# [ 84/400] Uploading new_image179.png OK (463 ms)
# [ 85/400] Uploading new_image180.png OK (484 ms)
# [ 86/400] Uploading new_image182.png OK (513 ms)
# [ 87/400] Uploading new_image166.png OK (1283 ms)
# [ 88/400] Uploading new_image170.png OK (1218 ms)
# [ 89/400] Uploading new_image18.png OK (746 ms)
# [ 90/400] Uploading new_image185.png OK (580 ms)
# [ 91/400] Uploading new_image189.png OK (438 ms)
# [ 92/400] Uploading new_image186.png OK (562 ms)
# [ 93/400] Uploading new_image174.png OK (1179 ms)
# [ 94/400] Uploading new_image187.png OK (642 ms)
# [ 95/400] Uploading new_image181.png OK (878 ms)
# [ 96/400] Uploading new_image19.png OK (518 ms)
# [ 97/400] Uploading new_image177.png OK (1020 ms)
# [ 98/400] Uploading new_image184.png OK (823 ms)
# [ 99/400] Uploading new_image192.png OK (479 ms)
# [100/400] Uploading new_image183.png OK (859 ms)
# [101/400] Uploading new_image173.png OK (1431 ms)
# [102/400] Uploading new_image188.png OK (801 ms)
# [103/400] Uploading new_image158.png OK (1802 ms)
# [104/400] Uploading new_image193.png OK (541 ms)
# [105/400] Uploading new_image197.png OK (433 ms)
# [106/400] Uploading new_image196.png OK (461 ms)
# [107/400] Uploading new_image198.png OK (479 ms)
# [108/400] Uploading new_image199.png OK (506 ms)
# [109/400] Uploading new_image190.png OK (901 ms)
# [110/400] Uploading new_image191.png OK (902 ms)
# [111/400] Uploading new_image20.png OK (511 ms)
# [112/400] Uploading new_image201.png OK (531 ms)
# [113/400] Uploading new_image200.png OK (629 ms)
# [114/400] Uploading new_image194.png OK (956 ms)
# [115/400] Uploading new_image203.png OK (674 ms)
# [116/400] Uploading new_image209.png OK (537 ms)
# [117/400] Uploading new_image21.png OK (539 ms)
# [118/400] Uploading new_image210.png OK (540 ms)
# [119/400] Uploading new_image2.png OK (965 ms)
# [120/400] Uploading new_image206.png OK (747 ms)
# [121/400] Uploading new_image207.png OK (751 ms)
# [122/400] Uploading new_image195.png OK (1109 ms)
# [123/400] Uploading new_image216.png OK (468 ms)
# [124/400] Uploading new_image215.png OK (516 ms)
# [125/400] Uploading new_image211.png OK (729 ms)
# [126/400] Uploading new_image202.png OK (1018 ms)
# [127/400] Uploading new_image208.png OK (921 ms)
# [128/400] Uploading new_image205.png OK (1006 ms)
# [129/400] Uploading new_image217.png OK (529 ms)
# [130/400] Uploading new_image218.png OK (424 ms)
# [131/400] Uploading new_image212.png OK (795 ms)
# [132/400] Uploading new_image204.png OK (1103 ms)
# [133/400] Uploading new_image219.png OK (452 ms)
# [134/400] Uploading new_image223.png OK (413 ms)
# [135/400] Uploading new_image22.png OK (573 ms)
# [136/400] Uploading new_image214.png OK (968 ms)
# [137/400] Uploading new_image221.png OK (626 ms)
# [138/400] Uploading new_image227.png OK (471 ms)
# [139/400] Uploading new_image224.png OK (619 ms)
# [140/400] Uploading new_image213.png OK (1162 ms)
# [141/400] Uploading new_image226.png OK (607 ms)
# [142/400] Uploading new_image220.png OK (853 ms)
# [143/400] Uploading new_image225.png OK (749 ms)
# [144/400] Uploading new_image232.png OK (502 ms)
# [145/400] Uploading new_image231.png OK (539 ms)
# [146/400] Uploading new_image228.png OK (667 ms)
# [147/400] Uploading new_image236.png OK (461 ms)
# [148/400] Uploading new_image229.png OK (747 ms)
# [149/400] Uploading new_image237.png OK (519 ms)
# [150/400] Uploading new_image23.png OK (850 ms)
# [151/400] Uploading new_image24.png OK (507 ms)
# [152/400] Uploading new_image235.png OK (815 ms)
# [153/400] Uploading new_image238.png OK (628 ms)
# [154/400] Uploading new_image245.png OK (415 ms)
# [155/400] Uploading new_image222.png OK (1229 ms)
# [156/400] Uploading new_image233.png OK (952 ms)
# [157/400] Uploading new_image239.png OK (683 ms)
# [158/400] Uploading new_image240.png OK (653 ms)
# [159/400] Uploading new_image230.png OK (1099 ms)
# [160/400] Uploading new_image247.png OK (487 ms)
# [161/400] Uploading new_image244.png OK (557 ms)
# [162/400] Uploading new_image246.png OK (553 ms)
# [163/400] Uploading new_image25.png OK (368 ms)
# [164/400] Uploading new_image248.png OK (514 ms)
# [165/400] Uploading new_image241.png OK (778 ms)
# [166/400] Uploading new_image250.png OK (527 ms)
# [167/400] Uploading new_image251.png OK (493 ms)
# [168/400] Uploading new_image242.png OK (924 ms)
# [169/400] Uploading new_image261.png OK (364 ms)
# [170/400] Uploading new_image243.png OK (949 ms)
# [171/400] Uploading new_image256.png OK (588 ms)
# [172/400] Uploading new_image249.png OK (892 ms)
# [173/400] Uploading new_image234.png OK (1537 ms)
# [174/400] Uploading new_image258.png OK (541 ms)
# [175/400] Uploading new_image254.png OK (670 ms)
# [176/400] Uploading new_image253.png OK (748 ms)
# [177/400] Uploading new_image252.png OK (810 ms)
# [178/400] Uploading new_image263.png OK (564 ms)
# [179/400] Uploading new_image265.png OK (376 ms)
# [180/400] Uploading new_image264.png OK (549 ms)
# [181/400] Uploading new_image269.png OK (336 ms)
# [182/400] Uploading new_image26.png OK (782 ms)
# [183/400] Uploading new_image255.png OK (920 ms)
# [184/400] Uploading new_image268.png OK (463 ms)
# [185/400] Uploading new_image260.png OK (901 ms)
# [186/400] Uploading new_image257.png OK (1001 ms)
# [187/400] Uploading new_image266.png OK (683 ms)
# [188/400] Uploading new_image27.png OK (458 ms)
# [189/400] Uploading new_image267.png OK (681 ms)
# [190/400] Uploading new_image259.png OK (1050 ms)
# [191/400] Uploading new_image276.png OK (429 ms)
# [192/400] Uploading new_image262.png OK (1017 ms)
# [193/400] Uploading new_image279.png OK (469 ms)
# [194/400] Uploading new_image274.png OK (663 ms)
# [195/400] Uploading new_image270.png OK (737 ms)
# [196/400] Uploading new_image272.png OK (820 ms)
# [197/400] Uploading new_image281.png OK (520 ms)
# [198/400] Uploading new_image28.png OK (608 ms)
# [199/400] Uploading new_image275.png OK (867 ms)
# [200/400] Uploading new_image273.png OK (982 ms)
# [201/400] Uploading new_image282.png OK (631 ms)
# [202/400] Uploading new_image286.png OK (558 ms)
# [203/400] Uploading new_image283.png OK (688 ms)
# [204/400] Uploading new_image277.png OK (996 ms)
# [205/400] Uploading new_image271.png OK (1135 ms)
# [206/400] Uploading new_image284.png OK (717 ms)
# [207/400] Uploading new_image287.png OK (622 ms)
# [208/400] Uploading new_image29.png OK (472 ms)
# [209/400] Uploading new_image280.png OK (920 ms)
# [210/400] Uploading new_image278.png OK (1061 ms)
# [211/400] Uploading new_image290.png OK (527 ms)
# [212/400] Uploading new_image293.png OK (387 ms)
# [213/400] Uploading new_image285.png OK (852 ms)
# [214/400] Uploading new_image292.png OK (481 ms)
# [215/400] Uploading new_image294.png OK (468 ms)
# [216/400] Uploading new_image291.png OK (735 ms)
# [217/400] Uploading new_image299.png OK (464 ms)
# [218/400] Uploading new_image302.png OK (436 ms)
# [219/400] Uploading new_image288.png OK (1101 ms)
# [220/400] Uploading new_image295.png OK (703 ms)
# [221/400] Uploading new_image306.png OK (423 ms)
# [222/400] Uploading new_image301.png OK (560 ms)
# [223/400] Uploading new_image298.png OK (675 ms)
# [224/400] Uploading new_image296.png OK (729 ms)
# [225/400] Uploading new_image297.png OK (746 ms)
# [226/400] Uploading new_image30.png OK (709 ms)
# [227/400] Uploading new_image309.png OK (534 ms)
# [228/400] Uploading new_image305.png OK (649 ms)
# [229/400] Uploading new_image289.png OK (1414 ms)
# [230/400] Uploading new_image3.png OK (902 ms)
# [231/400] Uploading new_image300.png OK (926 ms)
# [232/400] Uploading new_image310.png OK (535 ms)
# [233/400] Uploading new_image307.png OK (838 ms)
# [234/400] Uploading new_image31.png OK (686 ms)
# [235/400] Uploading new_image314.png OK (488 ms)
# [236/400] Uploading new_image304.png OK (975 ms)
# [237/400] Uploading new_image313.png OK (558 ms)
# [238/400] Uploading new_image320.png OK (408 ms)
# [239/400] Uploading new_image303.png OK (1094 ms)
# [240/400] Uploading new_image311.png OK (728 ms)
# [241/400] Uploading new_image32.png OK (545 ms)
# [242/400] Uploading new_image321.png OK (503 ms)
# [243/400] Uploading new_image312.png OK (831 ms)
# [244/400] Uploading new_image317.png OK (858 ms)
# [245/400] Uploading new_image323.png OK (542 ms)
# [246/400] Uploading new_image318.png OK (846 ms)
# [247/400] Uploading new_image325.png OK (518 ms)
# [248/400] Uploading new_image327.png OK (515 ms)
# [249/400] Uploading new_image326.png OK (616 ms)
# [250/400] Uploading new_image328.png OK (566 ms)
# [251/400] Uploading new_image333.png OK (415 ms)
# [252/400] Uploading new_image331.png OK (586 ms)
# [253/400] Uploading new_image33.png OK (655 ms)
# [254/400] Uploading new_image332.png OK (528 ms)
# [255/400] Uploading new_image322.png OK (948 ms)
# [256/400] Uploading new_image319.png OK (1179 ms)
# [257/400] Uploading new_image329.png OK (802 ms)
# [258/400] Uploading new_image334.png OK (623 ms)
# [259/400] Uploading new_image337.png OK (493 ms)
# [260/400] Uploading new_image336.png OK (507 ms)
# [261/400] Uploading new_image338.png OK (485 ms)
# [262/400] Uploading new_image308.png OK (1874 ms)
# [263/400] Uploading new_image34.png OK (456 ms)
# [264/400] Uploading new_image335.png OK (632 ms)
# [265/400] Uploading new_image341.png OK (363 ms)
# [266/400] Uploading new_image324.png OK (1222 ms)
# [267/400] Uploading new_image344.png OK (546 ms)
# [268/400] Uploading new_image349.png OK (407 ms)
# [269/400] Uploading new_image343.png OK (604 ms)
# [270/400] Uploading new_image345.png OK (590 ms)
# [271/400] Uploading new_image339.png OK (914 ms)
# [272/400] Uploading new_image340.png OK (866 ms)
# [273/400] Uploading new_image342.png OK (730 ms)
# [274/400] Uploading new_image352.png OK (481 ms)
# [275/400] Uploading new_image347.png OK (681 ms)
# [276/400] Uploading new_image330.png OK (1419 ms)
# [277/400] Uploading new_image35.png OK (625 ms)
# [278/400] Uploading new_image348.png OK (647 ms)
# [279/400] Uploading new_image346.png OK (769 ms)
# [280/400] Uploading new_image357.png OK (383 ms)
# [281/400] Uploading new_image358.png OK (376 ms)
# [282/400] Uploading new_image359.png OK (424 ms)
# [283/400] Uploading new_image356.png OK (484 ms)
# [284/400] Uploading new_image315.png OK (2288 ms)
# [285/400] Uploading new_image354.png OK (807 ms)
# [286/400] Uploading new_image350.png OK (995 ms)
# [287/400] Uploading new_image353.png OK (922 ms)
# [288/400] Uploading new_image355.png OK (871 ms)
# [289/400] Uploading new_image36.png OK (619 ms)
# [290/400] Uploading new_image316.png OK (2505 ms)
# [291/400] Uploading new_image363.png OK (520 ms)
# [292/400] Uploading new_image368.png OK (363 ms)
# [293/400] Uploading new_image362.png OK (598 ms)
# [294/400] Uploading new_image369.png OK (381 ms)
# [295/400] Uploading new_image370.png OK (352 ms)
# [296/400] Uploading new_image37.png OK (402 ms)
# [297/400] Uploading new_image351.png OK (1316 ms)
# [298/400] Uploading new_image366.png OK (794 ms)
# [299/400] Uploading new_image367.png OK (820 ms)
# [300/400] Uploading new_image364.png OK (907 ms)
# [301/400] Uploading new_image376.png OK (413 ms)
# [302/400] Uploading new_image372.png OK (583 ms)
# [303/400] Uploading new_image373.png OK (525 ms)
# [304/400] Uploading new_image374.png OK (553 ms)
# [305/400] Uploading new_image360.png OK (1074 ms)
# [306/400] Uploading new_image379.png OK (465 ms)
# [307/400] Uploading new_image382.png OK (346 ms)
# [308/400] Uploading new_image371.png OK (821 ms)
# [309/400] Uploading new_image365.png OK (1122 ms)
# [310/400] Uploading new_image38.png OK (587 ms)
# [311/400] Uploading new_image361.png OK (1256 ms)
# [312/400] Uploading new_image380.png OK (637 ms)
# [313/400] Uploading new_image375.png OK (764 ms)
# [314/400] Uploading new_image384.png OK (469 ms)
# [315/400] Uploading new_image383.png OK (542 ms)
# [316/400] Uploading new_image377.png OK (877 ms)
# [317/400] Uploading new_image392.png OK (372 ms)
# [318/400] Uploading new_image390.png OK (440 ms)
# [319/400] Uploading new_image391.png OK (430 ms)
# [320/400] Uploading new_image386.png OK (572 ms)
# [321/400] Uploading new_image378.png OK (1005 ms)
# [322/400] Uploading new_image381.png OK (925 ms)
# [323/400] Uploading new_image385.png OK (712 ms)
# [324/400] Uploading new_image395.png OK (448 ms)
# [325/400] Uploading new_image387.png OK (836 ms)
# [326/400] Uploading new_image399.png OK (463 ms)
# [327/400] Uploading new_image4.png OK (505 ms)
# [328/400] Uploading new_image42.png OK (406 ms)
# [329/400] Uploading new_image389.png OK (919 ms)
# [330/400] Uploading new_image41.png OK (557 ms)
# [331/400] Uploading new_image394.png OK (825 ms)
# [332/400] Uploading new_image396.png OK (862 ms)
# [333/400] Uploading new_image5.png OK (343 ms)
# [334/400] Uploading new_image43.png OK (658 ms)
# [335/400] Uploading new_image39.png OK (1140 ms)
# [336/400] Uploading new_image393.png OK (1044 ms)
# [337/400] Uploading new_image44.png OK (679 ms)
# [338/400] Uploading new_image46.png OK (631 ms)
# [339/400] Uploading new_image51.png OK (347 ms)
# [340/400] Uploading new_image50.png OK (369 ms)
# [341/400] Uploading new_image49.png OK (449 ms)
# [342/400] Uploading new_image47.png OK (628 ms)
# [343/400] Uploading new_image53.png OK (277 ms)
# [344/400] Uploading new_image48.png OK (610 ms)
# [345/400] Uploading new_image45.png OK (749 ms)
# [346/400] Uploading new_image397.png OK (1065 ms)
# [347/400] Uploading new_image56.png OK (303 ms)
# [348/400] Uploading new_image52.png OK (614 ms)
# [349/400] Uploading new_image60.png OK (367 ms)
# [350/400] Uploading new_image398.png OK (1302 ms)
# [351/400] Uploading new_image40.png OK (1185 ms)
# [352/400] Uploading new_image55.png OK (566 ms)
# [353/400] Uploading new_image61.png OK (490 ms)
# [354/400] Uploading new_image62.png OK (533 ms)
# [355/400] Uploading new_image66.png OK (532 ms)
# [356/400] Uploading new_image58.png OK (773 ms)
# [357/400] Uploading new_image63.png OK (732 ms)
# [358/400] Uploading new_image69.png OK (527 ms)
# [359/400] Uploading new_image57.png OK (941 ms)
# [360/400] Uploading new_image7.png OK (588 ms)
# [361/400] Uploading new_image6.png OK (981 ms)
# [362/400] Uploading new_image59.png OK (1035 ms)
# [363/400] Uploading new_image65.png OK (1002 ms)
# [364/400] Uploading new_image73.png OK (630 ms)
# [365/400] Uploading new_image76.png OK (491 ms)
# [366/400] Uploading new_image74.png OK (585 ms)
# [367/400] Uploading new_image75.png OK (547 ms)
# [368/400] Uploading new_image388.png OK (2364 ms)
# [369/400] Uploading new_image72.png OK (730 ms)
# [370/400] Uploading new_image79.png OK (370 ms)
# [371/400] Uploading new_image54.png OK (1348 ms)
# [372/400] Uploading new_image64.png OK (1113 ms)
# [373/400] Uploading new_image78.png OK (415 ms)
# [374/400] Uploading new_image67.png OK (1093 ms)
# [375/400] Uploading new_image71.png OK (875 ms)
# [376/400] Uploading new_image77.png OK (652 ms)
# [377/400] Uploading new_image8.png OK (583 ms)
# [378/400] Uploading new_image83.png OK (447 ms)
# [379/400] Uploading new_image84.png OK (449 ms)
# [380/400] Uploading new_image87.png OK (455 ms)
# [381/400] Uploading new_image9.png OK (497 ms)
# [382/400] Uploading new_image70.png OK (1283 ms)
# [383/400] Uploading new_image80.png OK (765 ms)
# [384/400] Uploading new_image81.png OK (718 ms)
# [385/400] Uploading new_image85.png OK (657 ms)
# [386/400] Uploading new_image88.png OK (624 ms)
# [387/400] Uploading new_image91.png OK (662 ms)
# [388/400] Uploading new_image68.png OK (1726 ms)
# [389/400] Uploading new_image86.png OK (818 ms)
# [390/400] Uploading new_image98.png OK (433 ms)
# [391/400] Uploading new_image96.png OK (525 ms)
# [392/400] Uploading new_image82.png OK (976 ms)
# [393/400] Uploading new_image95.png OK (641 ms)
# [394/400] Uploading new_image89.png OK (898 ms)
# [395/400] Uploading new_image97.png OK (536 ms)
# [396/400] Uploading new_image99.png OK (490 ms)
# [397/400] Uploading new_image94.png OK (801 ms)
# [398/400] Uploading new_image90.png OK (956 ms)
# [399/400] Uploading new_image93.png OK (925 ms)
# [400/400] Uploading new_image92.png OK (960 ms)
#
# Done. Files uploaded successful: 382. Files that failed to upload: 18.

# %% [markdown]
# # OpenMV Object Counting Script
# Once the model is trained we can use this script in OpenMV to run our model on an edge device and count objects that pass on the conveyor belt:

# %%
# Edge Impulse - OpenMV Object Detection Example

import sensor, image, time, os, tf, math, uos, gc

sensor.reset()                         # Reset and initialize the sensor.
sensor.set_pixformat(sensor.RGB565)    # Set pixel format to RGB565 (or GRAYSCALE)
sensor.set_framesize(sensor.QVGA)      # Set frame size to QVGA (320x240)
sensor.set_windowing((240, 240))       # Set 240x240 window.
sensor.skip_frames(time=2000)          # Let the camera adjust.

net = None
labels = None
min_confidence = 0.5

try:
    # load the model, alloc the model file on the heap if we have at least 64K free after loading
    net = tf.load("trained.tflite", load_to_fb=uos.stat('trained.tflite')[6] > (gc.mem_free() - (64*1024)))
except Exception as e:
    raise Exception('Failed to load "trained.tflite", did you copy the .tflite and labels.txt file onto the mass-storage device? (' + str(e) + ')')


try:
    labels = [line.rstrip('\n') for line in open("labels.txt")]
except Exception as e:
    raise Exception('Failed to load "labels.txt", did you copy the .tflite and labels.txt file onto the mass-storage device? (' + str(e) + ')')

colors = [ # Add more colors if you are detecting more than 7 types of classes at once.
    (255,   0,   0),
    (  0, 255,   0),
    (255, 255,   0),
    (  0,   0, 255),
    (255,   0, 255),
    (  0, 255, 255),
    (255, 255, 255),
]

clock = time.clock()



# Define the top of the image and the number of columns
TOP_Y = 100
NUM_COLS = 5
COL_WIDTH = int(sensor.width() / NUM_COLS)
# Define the factor of the width/height which determines the threshold
# for detection of the object's movement between frames:
DETECT_FACTOR = 1.5

# Initialize variables
count = [0] * NUM_COLS
previous_blobs = [[] for _ in range(NUM_COLS)]

while(True):
    clock.tick()

    img = sensor.snapshot()

    # detect() returns all objects found in the image (splitted out per class already)
    # we skip class index 0, as that is the background, and then draw circles of the center
    # of our objects

    # Initialize list of current blobs
    current_blobs = [[] for _ in range(NUM_COLS)]

    for i, detection_list in enumerate(net.detect(img, thresholds=[(math.ceil(min_confidence * 255), 255)])):
        if (i == 0): continue # background class
        if (len(detection_list) == 0): continue # no detections for this class?

        print("********** %s **********" % labels[i])
        for d in detection_list:
            [x, y, w, h] = d.rect()
            center_x = math.floor(x + (w / 2))
            center_y = math.floor(y + (h / 2))
            print('x %d\ty %d' % (center_x, center_y))
            img.draw_circle((center_x, center_y, 12), color=colors[i], thickness=2)

            # Check which column the blob is in
            col = int(x / COL_WIDTH)
            # Check if blob is within DETECT_FACTOR*h of a blob detected in the previous frame and treat as the same object
            for blob in previous_blobs[col]:
                if abs(x - blob[0]) < DETECT_FACTOR * (w + blob[2]) and abs(y - blob[1]) < DETECT_FACTOR * (h + blob[3]):
                # Check this blob has "moved" across the Y threshold
                    if blob[1] >= TOP_Y and y < TOP_Y:
                        # Increment count for this column if blob has left the top of the image
                        count[col] += 1
             # Add current blob to list
            current_blobs[col].append((x, y, w, h))

    print(clock.fps(), "fps", end="\n\n")

    # Update previous blobs
    previous_blobs = current_blobs

    # Print count for each column
    print("Count: ", count)
    img.draw_string(5, 2, "Object count: {}".format(sum(count)), color=(255, 255, 0))
    img.draw_string(5, 230, "FPS: {}".format(round(clock.fps())), color=(0, 0, 0))
